# %% [markdown]
# ## Brain MRI Images for Brain Tumor Detection

# %% [markdown]
# #Load data from kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-mri-images-for-brain-tumor-detection' dataset.
# Path to dataset files: /kaggle/input/brain-mri-images-for-brain-tumor-detection

# %% [markdown]
# **List sub diresctories**

# %%
import os
print(os.listdir(path))
# Out:
# ['no', 'yes', 'brain_tumor_dataset']

# %%
for class_name in os.listdir(path):
 class_path = os.path.join(path,class_name)
 print(class_path)
# Out:
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset

# %%
# creating path for yes/No  folder
import matplotlib.pyplot as plt
from PIL import Image
i=1
plt.figure(figsize=(8,2))
for class_name in os.listdir(path):
  class_path=os.path.join(path,class_name)
  if os.path.isdir(class_path):
    images = os.listdir(class_path)[:5]
    for img in images:
      img_path = os.path.join(class_path,img)
      if os.path.isfile(img_path):
        img = Image.open(img_path)
        plt.subplot(2,5,i)
        plt.imshow(img)
        plt.title(class_name)
        plt.axis('off')
        i+=1
plt.tight_layout()
plt.show()

# %%
for class_name in os.listdir(path):
  class_path=os.path.join(path,class_name)
  if os.path.isdir(class_path):
    count = len(os.listdir(class_path))
    print(class_name,count)
# Out:
# no 98
# yes 155
# brain_tumor_dataset 2

# %%
# create dataframe , labels
df =[]
for class_name in os.listdir(path):
  class_path=os.path.join(path,class_name)
  if os.path.isdir(class_path):
    images = os.listdir(class_path)
    for img in images:
      img_path = os.path.join(class_path,img)
      if os.path.isfile(img_path):
        df.append([img_path,class_name])

# %%
import pandas as pd
data = pd.DataFrame(df,columns=['img_path','labels'])

# %%
data
# Out:
#                                               img_path labels
# 0    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 1    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 2    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 3    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 4    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# ..                                                 ...    ...
# 248  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 249  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 250  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 251  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 252  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
#
# [253 rows x 2 columns]

# %%
# shuffle data
data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
data
# Out:
#                                               img_path labels
# 0    /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 1    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 2    /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 3    /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 4    /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# ..                                                 ...    ...
# 248  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 249  /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 250  /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 251  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
# 252  /kaggle/input/brain-mri-images-for-brain-tumor...    yes
#
# [253 rows x 2 columns]

# %% [markdown]
# #Split data for training,validation and testing

# %%
train_size = int(0.7 * len(df))
val_size = int(0.15 * len(df))
test_size = int(0.15*len(df))
print(f"train_size:{train_size} -----val_size:{val_size}----test_size:{test_size}")

train_data = data.iloc[:train_size]
# df.iloc[:,52500]
val_data = data.iloc[train_size:train_size + val_size]
# df.iloc[52500:52500+11250]
test_data = data.iloc[train_size + val_size:]
# df.iloc[52500+11250:]

# Display the sizes of each set
print(f'Training set size: {len(train_data)}')
print(f'Validation set size: {len(val_data)}')
print(f'Test set size: {len(test_data)}')
# Out:
# train_size:177 -----val_size:37----test_size:37
# Training set size: 177
# Validation set size: 37
# Test set size: 39

# %% [markdown]
# #find height and width of an image

# %%
image_path = data["img_path"][0]
image = Image.open(image_path)
width, height = image.size
print(f"height,width:{height,width}")
# Out:
# height,width:(237, 213)

# %% [markdown]
# #Image Preprocessing

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
# Normalization
data_generator = ImageDataGenerator(
    rescale=1.0/255, # Normalization: Pixel values go from 0–255 → 0–1
    rotation_range=40, #Randomly rotates image up to ±40 degrees
    width_shift_range=0.2, #Moves image left/right by 20%
    height_shift_range=0.2, # Moves image up/down by 20%
    shear_range=0.2, # Slants the image (like pushing it sideways)
    zoom_range=0.2, # Zoom in/out randomly
    horizontal_flip=True, #Flips image left ↔ right
    fill_mode='nearest' #This fills those gaps using nearest pixels
)

# %%
# train data
train_generator = data_generator.flow_from_dataframe(
  dataframe=train_data,
  x_col="img_path",
  y_col="labels",
  target_size=(img_height, img_width),
  batch_size=batch_size,
  class_mode="categorical",
  shuffle=True,
  seed=42
)
# Out:
# Found 177 validated image filenames belonging to 2 classes.

# %%
# test data
test_generator = data_generator.flow_from_dataframe(
  dataframe=test_data,
  x_col="img_path",
  y_col="labels",
  target_size=(img_height, img_width),
  batch_size=batch_size,
  class_mode="categorical",
  shuffle=True,
  seed=42
)

# val data
val_generator = data_generator.flow_from_dataframe(
  dataframe=val_data,
  x_col="img_path",
  y_col="labels",
  target_size=(img_height, img_width),
  batch_size=batch_size,
  class_mode="categorical",
  shuffle=True,
  seed=42
)
# Out:
# Found 39 validated image filenames belonging to 2 classes.
# Found 37 validated image filenames belonging to 2 classes.

# %%
for image_batch, labels_batch in train_generator:
    print(f"Train Shape: {image_batch.shape} (Batches = {len(train_generator)})")
    print(f"Train Label Shape: {labels_batch.shape}\n")
    break

for image_batch, labels_batch in val_generator:
    print(f"Validation Shape: {image_batch.shape} (Batches = {len(val_generator)})")
    print(f"Validation Label Shape: {labels_batch.shape}\n")
    break

for image_batch, labels_batch in test_generator:
    print(f"Test Shape: {image_batch.shape} (Batches = {len(test_generator)})")
    print(f"Test Label Shape: {labels_batch.shape}\n")
    break
# Out:
# Train Shape: (32, 224, 224, 3) (Batches = 6)
# Train Label Shape: (32, 2)
#
# Validation Shape: (32, 224, 224, 3) (Batches = 2)
# Validation Label Shape: (32, 2)
#
# Test Shape: (32, 224, 224, 3) (Batches = 2)
# Test Label Shape: (32, 2)

# %% [markdown]
# #CNN Model

# %%
from tensorflow.keras import layers,models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# %%
n_classes= 2
cnn_model = models.Sequential([
    layers.Input(shape=(224,224,3)),
    layers.Conv2D(32,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='sigmoid')])

# %%
cnn_model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), # Corrected by fully qualifying the loss function
                  optimizer=Adam(),
                  metrics=['accuracy'])

# %%
Cnn = cnn_model.fit(train_generator,
                    epochs=50,validation_data=val_generator,
                    verbose=1)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7345 - loss: 0.5274 - val_accuracy: 0.8378 - val_loss: 0.4541
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.6780 - loss: 0.6021 - val_accuracy: 0.7568 - val_loss: 0.4854
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7288 - loss: 0.5806 - val_accuracy: 0.7568 - val_loss: 0.5091
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7175 - loss: 0.5607 - val_accuracy: 0.8919 - val_loss: 0.4338
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7458 - loss: 0.5333 - val_accuracy: 0.7568 - val_loss: 0.4461
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7119 - loss: 0.5378 - val_accuracy: 0.8378 - val_loss: 0.5042
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7684 - loss: 0.4838 - val_accuracy: 0.8108 - val_loss: 0.3937
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.7514 - loss: 0.5575 - val_accuracy: 0.8108 - val_loss: 0.4373
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7345 - loss: 0.5472 - val_accuracy: 0.8108 - val_loss: 0.4314
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7345 - loss: 0.5439 - val_accuracy: 0.8378 - val_loss: 0.4060
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7288 - loss: 0.5450 - val_accuracy: 0.7838 - val_loss: 0.4379
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step - accuracy: 0.6949 - loss: 0.5907 - val_accuracy: 0.8108 - val_loss: 0.4916
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.6949 - loss: 0.5601 - val_accuracy: 0.8108 - val_loss: 0.4514
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7232 - loss: 0.5464 - val_accuracy: 0.8378 - val_loss: 0.4783
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7740 - loss: 0.4982 - val_accuracy: 0.7838 - val_loss: 0.4375
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7458 - loss: 0.5230 - val_accuracy: 0.8108 - val_loss: 0.4429
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7740 - loss: 0.4777 - val_accuracy: 0.8649 - val_loss: 0.3446
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7571 - loss: 0.5248 - val_accuracy: 0.7838 - val_loss: 0.4194
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7458 - loss: 0.4851 - val_accuracy: 0.7297 - val_loss: 0.4345
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7627 - loss: 0.5575 - val_accuracy: 0.7568 - val_loss: 0.5008
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7232 - loss: 0.5591 - val_accuracy: 0.8378 - val_loss: 0.4387
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.6836 - loss: 0.5663 - val_accuracy: 0.8378 - val_loss: 0.4619
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7966 - loss: 0.5142 - val_accuracy: 0.8108 - val_loss: 0.4452
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7345 - loss: 0.5249 - val_accuracy: 0.8108 - val_loss: 0.3678
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7175 - loss: 0.5896 - val_accuracy: 0.8108 - val_loss: 0.4454
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7401 - loss: 0.5369 - val_accuracy: 0.8649 - val_loss: 0.4814
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.8023 - loss: 0.5209 - val_accuracy: 0.8108 - val_loss: 0.4662
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7288 - loss: 0.5177 - val_accuracy: 0.8649 - val_loss: 0.3860
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.7514 - loss: 0.5250 - val_accuracy: 0.7838 - val_loss: 0.4110
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.8079 - loss: 0.4650 - val_accuracy: 0.8649 - val_loss: 0.3723
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7910 - loss: 0.4778 - val_accuracy: 0.8378 - val_loss: 0.3869
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7910 - loss: 0.4648 - val_accuracy: 0.8649 - val_loss: 0.3600
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7514 - loss: 0.5319 - val_accuracy: 0.7838 - val_loss: 0.4125
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7797 - loss: 0.4755 - val_accuracy: 0.8649 - val_loss: 0.3668
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7288 - loss: 0.5453 - val_accuracy: 0.8378 - val_loss: 0.4545
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7345 - loss: 0.5501 - val_accuracy: 0.7568 - val_loss: 0.5009
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - accuracy: 0.7740 - loss: 0.5162 - val_accuracy: 0.8649 - val_loss: 0.4058
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7401 - loss: 0.5299 - val_accuracy: 0.8108 - val_loss: 0.4276
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7910 - loss: 0.4747 - val_accuracy: 0.8378 - val_loss: 0.3617
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.8192 - loss: 0.4368 - val_accuracy: 0.7838 - val_loss: 0.4207
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.7853 - loss: 0.4692 - val_accuracy: 0.8378 - val_loss: 0.4048
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7062 - loss: 0.5628 - val_accuracy: 0.8649 - val_loss: 0.3565
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.8136 - loss: 0.4542 - val_accuracy: 0.8378 - val_loss: 0.4012
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7627 - loss: 0.4828 - val_accuracy: 0.8108 - val_loss: 0.4977
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7853 - loss: 0.5094 - val_accuracy: 0.8919 - val_loss: 0.3786
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7966 - loss: 0.4837 - val_accuracy: 0.9189 - val_loss: 0.3233
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7571 - loss: 0.5547 - val_accuracy: 0.7568 - val_loss: 0.5087
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7684 - loss: 0.5147 - val_accuracy: 0.8378 - val_loss: 0.4025
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.7797 - loss: 0.4649 - val_accuracy: 0.8378 - val_loss: 0.3864
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.7571 - loss: 0.4908 - val_accuracy: 0.7838 - val_loss: 0.4533

# %%
train_loss, train_accuracy = cnn_model.evaluate(train_generator, verbose=1)
print(f'Training accuracy: {train_accuracy:.4f}')

# Evaluate on the test data
test_loss, test_accuracy = cnn_model.evaluate(test_generator, verbose=1)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 925ms/step - accuracy: 0.7684 - loss: 0.4684
# Training accuracy: 0.7684
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7436 - loss: 0.5333
# Test accuracy: 0.7436

# %%
# Retrieve metrics from the training history
acc = Cnn.history['accuracy']
val_acc = Cnn.history['val_accuracy']
loss = Cnn.history['loss']
val_loss = Cnn.history['val_loss']

epochs_range = range(1, len(acc) + 1)

# Plot accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy for CNN')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss for CNN')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "three image.jpg"

# Load image with the correct target size matching model input
img = image.load_img(img_path, target_size=(img_height, img_width))  # Corrected to img_height, img_width

# Convert to array
img_array = image.img_to_array(img)

# Normalize
img_array = img_array / 255.0

# Add batch dimension
img_array = np.expand_dims(img_array, axis=0)

# %%
prediction = cnn_model.predict(img_array)
prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# array([[0.45687214, 0.57741666]], dtype=float32)

# %%
predicted_class = np.argmax(prediction)

print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: 1
